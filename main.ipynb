# %% [markdown]
# ###The all the Basic and specific knowledge about the RAG and Langchain

# %%
#### in the RAG and the langchain 
"""
    the main part of RAG is basically 2 part 
        1- Data Ingestion Pipeline 
        2- Retrival Pipeline 
    
Part-1 
    Data-Ingestion Pieline 
        here we will peerform the data inges pipeline first there are some few step to go with the process 
        
            1- Data input / Load -- 
            2- Data Chunking 
            3-Data Embedding 
            4-Data Storing in VectorDataBase 
            
            
    1- Data Load or Input pepeline 
        for that we ill use some kind of work 

                the data can be form of the  these types
                1-IN TEXT FORMAT 
                2-IN PDF FORMAT 
                3-In CSV FORMAT
                4-IN WEB-FORMAT 
                
                
        To work with all the format we need to do some import the some of langchain librery 
        
    
    
    
    2-Parcing the data for the chunk and split and to transfor
        
        For the chunking and spliting we will se the some langchain and the documentation for the loader
        we will do the chunking as we will given the data types we wre used different spliter 
        
        
    
    
    
    
    
    
    3- Embedding 
    
        Here we will use for the Embeddding models to embedding the text 
        
        there are more types of embedding models 
        
                1- OLLAMA
                2-Huggingface
                3-VectorDatabase-FAISS
                4-OPENAI 
    
    
    
        we need to import and export some embeddig model with also the API keys 
        




    4- Vector Data base 

        after conferming all the process we will use the vector embedding and the embedding 
        then we will use to store some kind of database 
        
            1-ChromaDB
            2-Pinecone
            3-
    

    
        
    







"""
# Out:
# '\n    the main part of RAG is basically 2 part \n        1- Data Ingestion Pipeline \n        2- Retrival Pipeline \n\nPart-1 \n    Data-Ingestion Pieline \n        here we will peerform the data inges pipeline first there are some few step to go with the process \n\n            1- Data input / Load -- \n            2- Data Chunking \n            3-Data Embedding \n            4-Data Storing in VectorDataBase \n\n\n    1- Data Load or Input pepeline \n        for that we ill use some kind of work \n\n                the data can be form of the  these types\n                1-IN TEXT FORMAT \n                2-IN PDF FORMAT \n                3-In CSV FORMAT\n                4-IN WEB-FORMAT \n\n\n        To work with all the format we need to do some import the some of langchain librery \n\n\n\n\n    2-Parcing the data for the chunk and split and to transfor\n\n        For the chunking and spliting we will se the some langchain and the documentation for the loader\n        we will do 
# ...
